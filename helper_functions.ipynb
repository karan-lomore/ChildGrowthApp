# %%
#libraries
import ipywidgets as widgets
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, clear_output, Markdown

# %%
def calculate_age_func(age_days):
    
    age_yrs = age_days / 365
    
    if age_yrs <= 5:
        types = 'below five'
    else:
        types = 'above five'
    
    return types

# %%
def dob_to_age_func(dob_ddmmyyyy):
    
    crnt_date = datetime.now()
    
    dob_format_chnge = datetime.strptime(dob_ddmmyyyy,'%Y-%m-%d')
    
    age_in_days = crnt_date - dob_format_chnge
    
    age_in_yrs = age_in_days.total_seconds() / (365.242 * 24 * 3600)
    
    age_in_yrs = round(age_in_yrs, 2)
    
    age_in_yrs_int = int(age_in_yrs)
    
    age_remaining_months = (age_in_yrs - age_in_yrs_int) * 12
    
    age_remaining_months_int = int(age_remaining_months)
    
    age_yrs_months_list = [age_in_yrs_int, age_remaining_months_int]
    
    return age_in_yrs_int, age_in_yrs, age_yrs_months_list

# %%
def age_yrs_func(age,months,guideline):
    if guideline =='IAP':
        age_ym = age+months/12
    
    elif guideline == 'WHO':
        age_ym = age*12+months
    elif guideline == 'CDC':
        age_ym = age*12+months/12
    return age_ym

# %%
def get_iap_pctl_func(gender, age):
        BMI = True
        fat = True
        age_ym = age
        if gender =='Male':
            weight_data = pd.read_csv('IAP-Dataset/male_weight_SD.csv')
            height_data = pd.read_csv('IAP-Dataset/male_height_SD.csv')
            bmi_data = pd.read_csv('IAP-dataset/male_bmi_SD.csv',sep = '\t')
            fatmass_pct_data = pd.read_csv('IAP-dataset/male_fatmass_pct_SD.csv')
            fatmass_data = pd.read_csv('IAP-dataset/male_fatmass_SD.csv')

        elif gender =='Female':
            weight_data = pd.read_csv('IAP-Dataset/female_weight_SD.csv')
            height_data = pd.read_csv('IAP-Dataset/female_height_SD.csv')
            bmi_data = pd.read_csv('IAP-dataset/female_bmi_SD.csv')
            fatmass_pct_data = pd.read_csv('IAP-dataset/female_fatmass_pct_SD.csv')
            fatmass_data = pd.read_csv('IAP-dataset/female_fatmass_SD.csv')
        
        rownumber_weight = weight_data[weight_data['Age'] == age_ym].index[0]
        weight_data.columns = ['Age','3rd','10th','25th','50th','75th','90th','95th']
        wt_coln = weight_data.columns
        
        rownumber_height = height_data[height_data['Age'] == age_ym].index[0]
        height_data.columns = ['Age', '3rd', '10th', '25th', '50th', '75th', '90th', '95th']
        ht_coln = height_data.columns
        
        rownumber_bmi = bmi_data[bmi_data['Age'] == age_ym].index[0]
        bmi_data.columns = ['Age', '3rd', '10th', '25th', '50th', '75th', '90th', '95th']
        bmi_coln = bmi_data.columns
        
        rownumber_fatmass_pct = fatmass_pct_data[fatmass_pct_data['Age'] == age_ym].index[0]
        fatmass_pct_data.columns = ['Age', '3rd', '10th', '25th', '50th', '75th','85th', '90th', '95th']
        fatmass_pct_coln = fatmass_pct_data.columns
        return weight_data, wt_coln, height_data, ht_coln,bmi_data,bmi_coln,fatmass_pct_data,fatmass_pct_coln
#weight_data, wt_coln, height_data, ht_coln,bmi_data,bmi_coln,fatmass_pct_data,fatmass_pct_coln = get_iap_pctl_func('Male',12)

# %%
def get_who_less_than_5_pctl_func(gender, age):
        months=0
        age_ym = age*12+months
        if age<5:
            if gender =='Male':
                    arm_circum_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/arm-circum-for-age/boys-table-arm-circumference-for-age-3-months-to-5-years-(percentiles).csv')
                    if age < 2:
                        bmi_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/bmi-for-age/bmi-boys-0-2-percentiles.csv')
                        height_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/height-for-age/boys-table---length-for-age-birth-to-2-years-(percentiles).csv')
                    else:
                        bmi_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/bmi-for-age/bmi-boys-2-5-percentiles.csv')
                        height_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/height-for-age/boys-table---height-for-age-2-to-5-years-(percentiles).csv')
                    head_circum_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/head-circum-for-age/boys-table--head-circumference-for-age-birth-to-5-years-(percentile).csv')
                    skin_fold_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/subscapular-skinfold-for-age/boys-table--subscapular-skinfold-for-age-3-months-to-5-years-(percentile).csv')
                    tricep_skin_fold_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/triceps-skinfold-for-age/boys-table--triceps-skinfold-for-age-3-months-to-5-years-(percentiles).csv')
                    weight_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/weight-for-age/boys-table---weight-for-age-birth-to-5-years-(percentiles).csv')


            elif gender == 'Female':
                    arm_circum_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/arm-circum-for-age/girls-table-arm-circumference-for-age-3-months-to-5-years-(percentiles).csv')
                    if age < 2:
                        bmi_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/bmi-for-age/bmi-girls-0-2-percentiles.csv')
                        height_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/height-for-age/girls-table---length-for-age-birth-to-2-years-(percentiles).csv')
                    else:
                        bmi_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/bmi-for-age/bmi-girls-2-5-percentiles.csv')
                        height_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/height-for-age/girls-table---height-for-age-2-to-5-years-(percentiles).csv')
                    head_circum_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/head-circum-for-age/girls-table--head-circumference-for-age-birth-to-5-years-(percentile).csv')
                    skin_fold_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/subscapular-skinfold-for-age/girls-table--subscapular-skinfold-for-age-3-months-to-5-years-(percentile).csv')
                    tricep_skin_fold_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/triceps-skinfold-for-age/girls-table--triceps-skinfold-for-age-3-months-to-5-years-(percentiles).csv')
                    weight_data = pd.read_csv('SamWorks/ProcessedData/WHO-Data/weight-for-age/girls-table---weight-for-age-birth-to-5-years-(percentiles).csv')

        
        bmi_data = bmi_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        height_data = height_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        head_circum_data = head_circum_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        arm_circum_data = arm_circum_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        skin_fold_data = skin_fold_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        tricep_skin_fold_data = tricep_skin_fold_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        weight_data = weight_data[['Month','1st', '3rd', '5th', '15th','25th', '50th', '75th', '85th', '95th', '97th', '99th']]
        rownumber_weight = weight_data[weight_data['Month'] == age_ym].index[0]
        rownumber_height = height_data[height_data['Month'] == age_ym].index[0]
        rownumber_head_circum = head_circum_data[head_circum_data['Month'] == age_ym].index[0]
        rownumber_arm_circum = arm_circum_data[arm_circum_data['Month'] == age_ym].index[0]
        rownumber_skin_fold = skin_fold_data[skin_fold_data['Month'] == age_ym].index[0]
        rownumber_tricep_skin_fold = tricep_skin_fold_data[tricep_skin_fold_data['Month'] == age_ym].index[0]
        rownumber_bmi = bmi_data[bmi_data['Month'] == age_ym].index[0]
        height_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th']
        ht_coln = height_data.columns
        weight_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th'] 
        wt_coln = weight_data.columns
        head_circum_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th'] 
        head_coln = head_circum_data.columns
        arm_circum_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th']
        arm_coln = arm_circum_data.columns
        skin_fold_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th']
        skin_coln = skin_fold_data.columns
        tricep_skin_fold_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th'] 
        tricep_coln = tricep_skin_fold_data.columns
        bmi_data.columns = ['Month','1st','3rd','5th','10th','25th','50th','75th','90th','95th','97th','99th'] 
        bmi_coln = bmi_data.columns
        return weight_data, wt_coln, height_data, ht_coln,bmi_data,bmi_coln,head_circum_data,head_coln,arm_circum_data,arm_coln,skin_fold_data,skin_coln,tricep_skin_fold_data,tricep_coln
weight_data, wt_coln, height_data, ht_coln,bmi_data,bmi_coln,head_circum_data,head_coln,arm_circum_data,arm_coln,skin_fold_data,skin_coln,tricep_skin_fold_data,tricep_coln = get_who_less_than_5_pctl_func('Male',1)

# %%
def iap_plotting(data_list, columns_list, parameter_list, variable_list, age_ym):
    
    plt.close()
    
    f, a = plt.subplots(2, 2, gridspec_kw={'width_ratios': [3, 3]}, figsize=(8, 8))
    
    if parameter_list[0] == 'Weight':
        data = data_list[0]
        columns_list = columns_list[0]
        parameter = parameter_list[0]
        variable = variable_list[0]
        #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
        a[0][0].plot(data.iloc[:,0],data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
        a[0][0].plot(data.iloc[:,0],data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
        a[0][0].plot(data.iloc[:,0],data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
        a[0][0].plot(data.iloc[:,0],data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
        a[0][0].plot(data.iloc[:,0],data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
        a[0][0].plot(data.iloc[:,0],data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')
        
        a[0][0].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
        a[0][0].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
        a[0][0].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
        a[0][0].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
        a[0][0].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
        #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
        x = 'Age'
        y = 4
 
            
        a[0][0].scatter(age_ym, variable, color = '#42a1f5', s = 30)
        #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')    
        
        if age_ym >= 9:
            a[0][0].set_xlim(age_ym-y,age_ym+y)
            a[0][0].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        else:
            a[0][0].set_xlim(5, age_ym+y)
            a[0][0].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        
        a[0][0].set_xlabel('{}'.format('Age (years)'), fontsize=10)
        a[0][0].set_ylabel('{}'.format('Weight (kg.)'), fontsize=10)
        a[0][0].xaxis.set_tick_params(labelsize=8)
        a[0][0].yaxis.set_tick_params(labelsize=8)
        
    
    if parameter_list[1] =='Height':
        data = data_list[1]
        columns_list = columns_list[1]
        parameter = parameter_list[1]
        variable = variable_list[1]
        #a[0][1].plot(data.iloc[:,0],data['3rd'], linestyle='-', color = '#cf3933')
        a[0][1].plot(data.iloc[:,0],data['10th'], linestyle='-', color = '#e2c644',label='Below 10th percentile')
        a[0][1].plot(data.iloc[:,0],data['25th'], linestyle='-', color = '#dcdcdc',label='10th-25th percentile')
        a[0][1].plot(data.iloc[:,0],data['50th'], linestyle='-', color = '#bfbfbf',label='25th-50th percentile')
        a[0][1].plot(data.iloc[:,0],data['75th'], linestyle='-', color = '#dcdcdc',label='50-75th percentile')
        a[0][1].plot(data.iloc[:,0],data['90th'], linestyle='-', color = '#dcdcdc',label='75th-90th percentile')
        a[0][1].plot(data.iloc[:,0],data['95th'], linestyle='-', color = '#dcdcdc',label='Above 90th percentile')
        a[0][1].stackplot(data.iloc[:,0].values,data['95th'], color = '#c5dcc7')
        a[0][1].stackplot(data.iloc[:,0].values,data['90th'], color = '#c5dcc7')
        a[0][1].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
        a[0][1].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
        a[0][1].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
        #a[0][1].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

        x = 'Age'
        y = 4

            
        a[0][1].scatter(age_ym, variable, color = '#42a1f5',s = 30)
        #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')    
        
        if age_ym >= 9:
            a[0][1].set_xlim(age_ym-y,age_ym+y)
            a[0][1].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        else:
            a[0][1].set_xlim(5,age_ym+y)
            a[0][1].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        
        a[0][1].set_xlabel('{}'.format('Age (years)'), fontsize=10)
        a[0][1].set_ylabel('{}'.format('Height (cm.)'), fontsize=10)
        a[0][1].xaxis.set_tick_params(labelsize=8)
        a[0][1].yaxis.set_tick_params(labelsize=8)
        
    if parameter_list[2] == 'BMI':
            data = data_list[2]
            columns_list = columns_list[2]
            parameter = parameter_list[2]
            variable = variable_list[2]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[1][0].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[1][0].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[1][0].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[1][0].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[1][0].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[1][0].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
            x = 'Age'
            y = 4


            a[1][0].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 9:
                a[1][0].set_xlim(age_ym-y,age_ym+y)
                a[1][0].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[1][0].set_xlim(5, age_ym+y)
                a[1][0].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            a[1][0].set_xlabel('{}'.format('Age (years)'), fontsize=10)
            a[1][0].set_ylabel('{}'.format('BMI'), fontsize=10)
            a[1][0].xaxis.set_tick_params(labelsize=8)
            a[1][0].yaxis.set_tick_params(labelsize=8)
        
    if parameter_list[3] == 'BodyFat':
            data = data_list[3]
            columns_list = columns_list[-1]
            parameter = parameter_list[3]
            variable = variable_list[3]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[1][1].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[1][1].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[1][1].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[1][1].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[1][1].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[1][1].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
            x = 'Age'
            y = 4


            a[1][1].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 9:
                a[1][1].set_xlim(age_ym-y,age_ym+y)
                a[1][1].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[1][1].set_xlim(5, age_ym+y)
                a[1][1].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            a[1][1].set_xlabel('{}'.format('Age (years)'), fontsize=10)
            a[1][1].set_ylabel('{}'.format('Body Fat%'), fontsize=10)
            a[1][1].xaxis.set_tick_params(labelsize=8)
            a[1][1].yaxis.set_tick_params(labelsize=8)

        

    f.suptitle('Child Growth Assessment') 
    f.tight_layout(pad=2.0)
    plt.show()
    
    return 
#iap_plotting([weight_data, height_data, bmi_data,fatmass_pct_data], [wt_coln, ht_coln,bmi_coln,fatmass_pct_coln], ['Weight', 'Height','BMI','BodyFat'], [50, 130,23.4,10], 12.0)

# %%
def who_less_than_5_plotting(data_list, columns_list, parameter_list, variable_list, age_ym):
    
    plt.close()
    
    f, a = plt.subplots(nrows=2, ncols=3,  figsize=(8, 16))
    
    if parameter_list[0] == 'Weight':
        data = data_list[0]
        columns_list = columns_list[0]
        parameter = parameter_list[0]
        variable = variable_list[0]
        #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
        a[0][0].plot(data.iloc[:,0],data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
        a[0][0].plot(data.iloc[:,0],data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
        a[0][0].plot(data.iloc[:,0],data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
        a[0][0].plot(data.iloc[:,0],data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
        a[0][0].plot(data.iloc[:,0],data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
        a[0][0].plot(data.iloc[:,0],data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')
        
        a[0][0].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
        a[0][0].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
        a[0][0].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
        a[0][0].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
        a[0][0].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
        #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
        x = 'Month'
        y = 48
 
            
        a[0][0].scatter(age_ym, variable, color = '#42a1f5', s = 30)
        #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')    
        
        if age_ym >= 48:
            a[0][0].set_xlim(age_ym-y,age_ym+y)
            a[0][0].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        else:
            a[0][0].set_xlim(0, age_ym+y)
            a[0][0].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        
        a[0][0].set_xlabel('{}'.format('Months'), fontsize=10)
        a[0][0].set_ylabel('{}'.format('Weight (kg.)'), fontsize=10)
        a[0][0].xaxis.set_tick_params(labelsize=8)
        a[0][0].yaxis.set_tick_params(labelsize=8)
        
    
    if parameter_list[1] =='Height':
        data = data_list[1]
        columns_list = columns_list[1]
        parameter = parameter_list[1]
        variable = variable_list[1]
        #a[0][1].plot(data.iloc[:,0],data['3rd'], linestyle='-', color = '#cf3933')
        a[0][1].plot(data.iloc[:,0],data['10th'], linestyle='-', color = '#e2c644',label='Below 10th percentile')
        a[0][1].plot(data.iloc[:,0],data['25th'], linestyle='-', color = '#dcdcdc',label='10th-25th percentile')
        a[0][1].plot(data.iloc[:,0],data['50th'], linestyle='-', color = '#bfbfbf',label='25th-50th percentile')
        a[0][1].plot(data.iloc[:,0],data['75th'], linestyle='-', color = '#dcdcdc',label='50-75th percentile')
        a[0][1].plot(data.iloc[:,0],data['90th'], linestyle='-', color = '#dcdcdc',label='75th-90th percentile')
        a[0][1].plot(data.iloc[:,0],data['95th'], linestyle='-', color = '#dcdcdc',label='Above 90th percentile')
        a[0][1].stackplot(data.iloc[:,0].values,data['95th'], color = '#c5dcc7')
        a[0][1].stackplot(data.iloc[:,0].values,data['90th'], color = '#c5dcc7')
        a[0][1].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
        a[0][1].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
        a[0][1].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
        #a[0][1].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

        x = 'Month'
        y = 48
            
        a[0][1].scatter(age_ym, variable, color = '#42a1f5',s = 30)
        #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        a[0][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')    
        
        if age_ym >= 48:
            a[0][1].set_xlim(age_ym-y,age_ym+y)
            a[0][1].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        else:
            a[0][1].set_xlim(0,age_ym+y)
            #a[0][1].set_ylim(float(data.loc[data[x] == age_ym, '10th'].to_list()[0]), float(data.loc[data[x] == age_ym+y, '95th'].to_list()[0]))
        
        a[0][1].set_xlabel('{}'.format('Months'), fontsize=10)
        a[0][1].set_ylabel('{}'.format('Height (cm.)'), fontsize=10)
        a[0][1].xaxis.set_tick_params(labelsize=8)
        a[0][1].yaxis.set_tick_params(labelsize=8)
        
    if parameter_list[2] == 'BMI':
            data = data_list[2]
            columns_list = columns_list[2]
            parameter = parameter_list[2]
            variable = variable_list[2]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[1][0].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[1][0].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[1][0].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[1][0].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[1][0].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[1][0].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[1][0].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
            x = 'Month'
            y = 48


            a[1][0].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][0].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                a[1][0].set_xlim(age_ym-y,age_ym+y)
                a[1][0].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[1][0].set_xlim(0, age_ym+y)
                #a[1][0].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            a[1][0].set_xlabel('{}'.format('Months'), fontsize=10)
            a[1][0].set_ylabel('{}'.format('BMI'), fontsize=10)
            a[1][0].xaxis.set_tick_params(labelsize=8)
            a[1][0].yaxis.set_tick_params(labelsize=8)
        
    if parameter_list[3] == 'HeadCircum':
            data = data_list[3]
            columns_list = columns_list[3]
            parameter = parameter_list[3]
            variable = variable_list[3]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[1][1].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[1][1].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[1][1].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[1][1].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[1][1].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[1][1].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[1][1].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            a[1][1].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][1].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                a[1][1].set_xlim(age_ym-y,age_ym+y)
                a[1][1].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[1][1].set_xlim(0, age_ym+y)
                #a[1][1].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            a[1][1].set_xlabel('{}'.format('Months'), fontsize=10)
            a[1][1].set_ylabel('{}'.format('Head Circumference'), fontsize=10)
            a[1][1].xaxis.set_tick_params(labelsize=8)
            a[1][1].yaxis.set_tick_params(labelsize=8)

    if parameter_list[4] == 'ArmCircum':
            data = data_list[4]
            columns_list = columns_list[4]
            parameter = parameter_list[4]
            variable = variable_list[4]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[0][2].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[0][2].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[0][2].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[0][2].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[0][2].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[0][2].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[0][2].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[0][2].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[0][2].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[0][2].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[0][2].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            a[0][2].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[0][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                a[0][2].set_xlim(age_ym-y,age_ym+y)
                a[0][2].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[0][2].set_xlim(0, age_ym+y)
                #a[0][2].set_ylim(float(data.loc[data[x] == age_ym, '10th'].to_list()[0]), float(data.loc[data[x] == age_ym+y, '95th'].to_list()[0]))

            a[0][2].set_xlabel('{}'.format('Months'), fontsize=10)
            a[0][2].set_ylabel('{}'.format('Arm Circumference'), fontsize=10)
            a[0][2].xaxis.set_tick_params(labelsize=8)
            a[0][2].yaxis.set_tick_params(labelsize=8)
    '''
    if parameter_list[5] == 'SkinFold':
            data = data_list[5]
            columns_list = columns_list[5]
            parameter = parameter_list[5]
            variable = variable_list[5]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[0][3].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[0][3].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[0][3].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[0][3].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[0][3].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[0][3].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[0][3].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[0][3].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[0][3].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[0][3].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[0][3].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            a[0][3].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[0][3].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][3].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][3].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][3].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][3].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[0][3].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                a[0][3].set_xlim(age_ym-y,age_ym+y)
                a[0][3].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[0][3].set_xlim(0, age_ym+y)
                a[0][3].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            a[0][3].set_xlabel('{}'.format('Months'), fontsize=10)
            a[0][3].set_ylabel('{}'.format('Skin Fold'), fontsize=10)
            a[0][3].xaxis.set_tick_params(labelsize=8)
            a[0][3].yaxis.set_tick_params(labelsize=8)
    '''
    if parameter_list[6] == 'TricepSkinFold':
            data = data_list[6]
            columns_list = columns_list[6]
            parameter = parameter_list[6]
            variable = variable_list[6]
            #a[0][0].plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            a[1][2].plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            a[1][2].plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            a[1][2].plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            a[1][2].plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            a[1][2].plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            a[1][2].plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            a[1][2].stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            a[1][2].stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            a[1][2].stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            a[1][2].stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            a[1][2].stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #a[0][0].stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            a[1][2].scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            a[1][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            a[1][2].text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                a[1][2].set_xlim(age_ym-y,age_ym+y)
                a[1][2].set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                a[1][2].set_xlim(0, age_ym+y)
                #a[1][2].set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            a[1][2].set_xlabel('{}'.format('Months'), fontsize=10)
            a[1][2].set_ylabel('{}'.format('Tricep Skin Fold'), fontsize=10)
            a[1][2].xaxis.set_tick_params(labelsize=8)
            a[1][2].yaxis.set_tick_params(labelsize=8)
        

        

    f.suptitle('Child Growth Assessment') 
    #f.tight_layout(pad=2.0)
    plt.show()
    
    return 
who_less_than_5_plotting([weight_data, height_data, bmi_data,head_circum_data,arm_circum_data,skin_fold_data,tricep_skin_fold_data], [wt_coln, ht_coln,bmi_coln,head_coln,arm_coln,skin_coln,tricep_coln], ['Weight', 'Height','BMI','BodyFat','HeadCircum','ArmCircum','SkinFold','TricepSkinFold'], [12, 74,14,45,14,6,9], 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\child_growth_prototype\.venv\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# E:\child_growth_prototype\.venv\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
def bmi_fat_pct_func(age, gender, bmi):
    fatmass_pct=0
   # taken from female data generated correlation saha sir data 
    if 2 <= age <= 7:
        if gender == 'male' or gender == 'female':
            fatmass_pct = (-0.05 * age) + (1.034 * bmi) + 4.39
    
    if 7 < age <= 18:
        if gender == 'male':
            fatmass_pct = (-0.05 * age) + (1.034 * bmi) + 4.39 - (3.6 * age / 18) # age reduce fat pct in boys with respect to girls over age
        elif gender == 'female':
            fatmass_pct = (-0.05 * age) + (1.034 * bmi) + 4.39

    fatmass_pct = round(fatmass_pct, 1)
    
    return fatmass_pct

# %%
#calculations
def bmi_func(age,weight,height):
    bmi = round(((weight/(height**2))*10000),2)
    return bmi

# %%
tricep_skin_fold_data.loc[tricep_skin_fold_data['Month'] == 12, '95th'].to_list()[0]
# Out:
# 11.2

# %%
def who_less_than_5_plotting(data_list, columns_list, parameter_list, variable_list, age_ym):
    
    plt.close()
    
    fig, axes = plt.subplots(ncols=3, nrows=3, gridspec_kw={'width_ratios': [1, 1, 1], 'height_ratios': [1, 1, 1]}, figsize=(15, 15))

    ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9 = axes.flatten()
    ax7.set_visible(False)
    ax9.set_visible(False)
    
    if parameter_list[0] == 'Weight':
        data = data_list[0]
        columns_list = columns_list[0]
        parameter = parameter_list[0]
        variable = variable_list[0]
        #ax1.plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
        ax1.plot(data.iloc[:,0],data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
        ax1.plot(data.iloc[:,0],data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
        ax1.plot(data.iloc[:,0],data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
        ax1.plot(data.iloc[:,0],data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
        ax1.plot(data.iloc[:,0],data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
        ax1.plot(data.iloc[:,0],data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')
        
        ax1.stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
        ax1.stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
        ax1.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
        ax1.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
        ax1.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
        #ax1.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
        x = 'Month'
        y = 48
 
            
        ax1.scatter(age_ym, variable, color = '#42a1f5', s = 30)
        #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
        ax1.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax1.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax1.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax1.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax1.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax1.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')    
        
        if age_ym >= 48:
            ax1.set_xlim(age_ym-y,age_ym+y)
            ax1.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        else:
            ax1.set_xlim(0, age_ym+y)
            ax1.set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        
        ax1.set_xlabel('{}'.format('Months'), fontsize=10)
        ax1.set_ylabel('{}'.format('Weight (kg.)'), fontsize=10)
        ax1.xaxis.set_tick_params(labelsize=8)
        ax1.yaxis.set_tick_params(labelsize=8)
        
    
    if parameter_list[1] =='Height':
        data = data_list[1]
        columns_list = columns_list[1]
        parameter = parameter_list[1]
        variable = variable_list[1]
        #ax2.plot(data.iloc[:,0],data['3rd'], linestyle='-', color = '#cf3933')
        ax2.plot(data.iloc[:,0],data['10th'], linestyle='-', color = '#e2c644',label='Below 10th percentile')
        ax2.plot(data.iloc[:,0],data['25th'], linestyle='-', color = '#dcdcdc',label='10th-25th percentile')
        ax2.plot(data.iloc[:,0],data['50th'], linestyle='-', color = '#bfbfbf',label='25th-50th percentile')
        ax2.plot(data.iloc[:,0],data['75th'], linestyle='-', color = '#dcdcdc',label='50-75th percentile')
        ax2.plot(data.iloc[:,0],data['90th'], linestyle='-', color = '#dcdcdc',label='75th-90th percentile')
        ax2.plot(data.iloc[:,0],data['95th'], linestyle='-', color = '#dcdcdc',label='Above 90th percentile')
        ax2.stackplot(data.iloc[:,0].values,data['95th'], color = '#c5dcc7')
        ax2.stackplot(data.iloc[:,0].values,data['90th'], color = '#c5dcc7')
        ax2.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
        ax2.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
        ax2.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
        #ax2.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

        x = 'Month'
        y = 48
            
        ax2.scatter(age_ym, variable, color = '#42a1f5',s = 30)
        #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
        ax2.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax2.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax2.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax2.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax2.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')
        ax2.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
        verticalalignment='center')    
        
        if age_ym >= 48:
            ax2.set_xlim(age_ym-y,age_ym+y)
            ax2.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
        else:
            ax2.set_xlim(0,age_ym+y)
            #ax2.set_ylim(float(data.loc[data[x] == age_ym, '10th'].to_list()[0]), float(data.loc[data[x] == age_ym+y, '95th'].to_list()[0]))
        
        ax2.set_xlabel('{}'.format('Months'), fontsize=10)
        ax2.set_ylabel('{}'.format('Height (cm.)'), fontsize=10)
        ax2.xaxis.set_tick_params(labelsize=8)
        ax2.yaxis.set_tick_params(labelsize=8)
        
    if parameter_list[2] == 'BMI':
            data = data_list[2]
            columns_list = columns_list[2]
            parameter = parameter_list[2]
            variable = variable_list[2]
            #ax1.plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            ax3.plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            ax3.plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            ax3.plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            ax3.plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            ax3.plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            ax3.plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            ax3.stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            ax3.stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            ax3.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            ax3.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            ax3.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #ax1.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        
 
            x = 'Month'
            y = 48


            ax3.scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            ax3.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax3.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax3.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax3.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax3.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax3.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                ax3.set_xlim(age_ym-y,age_ym+y)
                ax3.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                ax3.set_xlim(0, age_ym+y)
                #ax3.set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            ax3.set_xlabel('{}'.format('Months'), fontsize=10)
            ax3.set_ylabel('{}'.format('BMI'), fontsize=10)
            ax3.xaxis.set_tick_params(labelsize=8)
            ax3.yaxis.set_tick_params(labelsize=8)
        
    if parameter_list[3] == 'HeadCircum':
            data = data_list[3]
            columns_list = columns_list[3]
            parameter = parameter_list[3]
            variable = variable_list[3]
            #ax1.plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            ax4.plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            ax4.plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            ax4.plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            ax4.plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            ax4.plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            ax4.plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            ax4.stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            ax4.stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            ax4.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            ax4.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            ax4.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #ax1.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            ax4.scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            ax4.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax4.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax4.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax4.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax4.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax4.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                ax4.set_xlim(age_ym-y,age_ym+y)
                ax4.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                ax4.set_xlim(0, age_ym+y)
                #ax4.set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            ax4.set_xlabel('{}'.format('Months'), fontsize=10)
            ax4.set_ylabel('{}'.format('Head Circumference'), fontsize=10)
            ax4.xaxis.set_tick_params(labelsize=8)
            ax4.yaxis.set_tick_params(labelsize=8)

    if parameter_list[4] == 'ArmCircum':
            data = data_list[4]
            columns_list = columns_list[4]
            parameter = parameter_list[4]
            variable = variable_list[4]
            #ax1.plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            ax5.plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            ax5.plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            ax5.plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            ax5.plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            ax5.plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            ax5.plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            ax5.stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            ax5.stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            ax5.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            ax5.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            ax5.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #ax1.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            ax5.scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            ax5.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax5.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax5.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax5.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax5.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax5.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                ax5.set_xlim(age_ym-y,age_ym+y)
                ax5.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                ax5.set_xlim(0, age_ym+y)
                #ax5.set_ylim(float(data.loc[data[x] == age_ym, '10th'].to_list()[0]), float(data.loc[data[x] == age_ym+y, '95th'].to_list()[0]))

            ax5.set_xlabel('{}'.format('Months'), fontsize=10)
            ax5.set_ylabel('{}'.format('Arm Circumference'), fontsize=10)
            ax5.xaxis.set_tick_params(labelsize=8)
            ax5.yaxis.set_tick_params(labelsize=8)
 
    if parameter_list[5] == 'SkinFold':
            data = data_list[5]
            columns_list = columns_list[5]
            parameter = parameter_list[5]
            variable = variable_list[5]
            #ax1.plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            ax6.plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            ax6.plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            ax6.plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            ax6.plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            ax6.plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            ax6.plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            ax6.stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            ax6.stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            ax6.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            ax6.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            ax6.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #ax1.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            ax6.scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            ax6.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax6.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax6.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax6.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax6.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax6.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                ax6.set_xlim(age_ym-y,age_ym+y)
                ax6.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                ax6.set_xlim(0, age_ym+y)
                ax6.set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            ax6.set_xlabel('{}'.format('Months'), fontsize=10)
            ax6.set_ylabel('{}'.format('Skin Fold'), fontsize=10)
            ax6.xaxis.set_tick_params(labelsize=8)
            ax6.yaxis.set_tick_params(labelsize=8)

    if parameter_list[6] == 'TricepSkinFold':
            data = data_list[6]
            columns_list = columns_list[6]
            parameter = parameter_list[6]
            variable = variable_list[6]
            #ax1.plot(data.iloc[:,0].values,data['3rd'], linestyle='-', color = '#cf3933')
            ax8.plot(data.iloc[:,0].values,data['10th'], linestyle='-', color = '#cf3933',label='Below 10th percentile')
            ax8.plot(data.iloc[:,0].values,data['25th'], linestyle='-', color = '#7f7f7f',label='10th-25th percentile')
            ax8.plot(data.iloc[:,0].values,data['50th'], linestyle='-', color = '#468d50',label='25th-50th percentile')
            ax8.plot(data.iloc[:,0].values,data['75th'], linestyle='-', color = '#7f7f7f',label='50-75th percentile')
            ax8.plot(data.iloc[:,0].values,data['90th'], linestyle='-', color = '#cf3933',label='75th-90th percentile')
            ax8.plot(data.iloc[:,0].values,data['95th'], linestyle='-', color = '#cf3933',label='Above 90th percentile')

            ax8.stackplot(data.iloc[:,0].values,data['95th'], color = '#efbdbd')
            ax8.stackplot(data.iloc[:,0].values,data['90th'], color = '#f9e7b2')
            ax8.stackplot(data.iloc[:,0].values,data['75th'],color = '#c5dcc7') 
            ax8.stackplot(data.iloc[:,0].values,data['25th'],color = '#f9e7b2') 
            ax8.stackplot(data.iloc[:,0].values,data['10th'],color = '#efbdbd') 
            #ax1.stackplot(data.iloc[:,0].values,data['3rd'],color = '#efbdbd')
        

            x = 'Month'
            y = 48

            ax8.scatter(age_ym, variable, color = '#42a1f5', s = 30)
            #plt.text(age_ym+y+0.2, data.loc[data[x] == age_ym+y, '3rd'], '3rd', fontsize=12, horizontalalignment='center',verticalalignment='center')
            ax8.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '10th'], '10th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax8.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '25th'], '25th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax8.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '50th'], '50th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax8.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '75th'], '75th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax8.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '90th'], '90th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')
            ax8.text(age_ym+y+0.4, data.loc[data[x] == age_ym+y, '95th'], '95th', fontsize=8, horizontalalignment='center',
            verticalalignment='center')    

            if age_ym >= 48:
                ax8.set_xlim(age_ym-y,age_ym+y)
                ax8.set_ylim(data.loc[data[x] == age_ym-y, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])
            else:
                ax8.set_xlim(0, age_ym+y)
                #ax8.set_ylim(data.loc[data[x] == age_ym, '10th'].to_list()[0], data.loc[data[x] == age_ym+y, '95th'].to_list()[0])

            ax8.set_xlabel('{}'.format('Months'), fontsize=10)
            ax8.set_ylabel('{}'.format('Tricep Skin Fold'), fontsize=10)
            ax8.xaxis.set_tick_params(labelsize=8)
            ax8.yaxis.set_tick_params(labelsize=8)
        

        

    fig.suptitle('Child Growth Assessment') 
    #fig.tight_layout(pad=2.0)
    plt.show()
    
    return 
who_less_than_5_plotting([weight_data, height_data, bmi_data,head_circum_data,arm_circum_data,skin_fold_data,tricep_skin_fold_data], [wt_coln, ht_coln,bmi_coln,head_coln,arm_coln,skin_coln,tricep_coln], ['Weight', 'Height','BMI','BodyFat','HeadCircum','ArmCircum','SkinFold','TricepSkinFold'], [12, 74,14,45,14,6,9], 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\child_growth_prototype\.venv\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# E:\child_growth_prototype\.venv\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...
